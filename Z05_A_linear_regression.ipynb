# %% [markdown]
# # Regresja liniowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
M1 = np.vstack( (np.ones_like(x), x) ).T
p1 = np.linalg.lstsq(M1, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_1 = lambda x: p1[0][1] * x +p1[0][0]

# %%
x_f_lr_1 = np.linspace(0., 3, 200)
y_f_lr_1 = f_lr_1(x_f_lr_1)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr_1, y_f_lr_1, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack((np.ones_like(x), x, x**2)).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_2 = lambda x: p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0]

# %%
x_f_lr_2 = np.linspace(0., 3, 200)
y_f_lr_2 = f_lr_2(x_f_lr_2)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr_2, y_f_lr_2, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M3 = np.vstack((np.ones_like(x), x, x**2, x**3)).T
p3 = np.linalg.lstsq(M3, y, rcond=None)

# %%
f_lr_3 = lambda x: p3[0][3]*pow(x,3) + p3[0][2]*pow(x,2) + p3[0][1] * x + p3[0][0] 
x_f_lr_3 = np.linspace(0., 3, 200)
y_f_lr_3 = f_lr_3(x_f_lr_3)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr_3, y_f_lr_3, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M4 = np.vstack((np.ones_like(x), x, x**2, x**3, x**4)).T
p4 = np.linalg.lstsq(M4, y, rcond=None)

# %%
f_lr_4 = lambda x: p4[0][4]*pow(x,4) + p4[0][3]*pow(x,3) + p4[0][2]*pow(x,2) + p4[0][1] * x + p4[0][0] 
x_f_lr_4 = np.linspace(0., 3, 200)
y_f_lr_4 = f_lr_4(x_f_lr_4)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr_4, y_f_lr_4, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M5 = np.vstack((np.ones_like(x), x, x**2, x**3, x**4, x**5)).T
p5 = np.linalg.lstsq(M5, y, rcond=None)

# %%
f_lr_5 = lambda x: p5[0][5]*pow(x,5) + p5[0][4]*pow(x,4) + p5[0][3]*pow(x,3) + \
                   p5[0][2]*pow(x,2) + p5[0][1] * x + p5[0][0] 
x_f_lr_5 = np.linspace(0., 3, 200)
y_f_lr_5 = f_lr_5(x_f_lr_5)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr_5, y_f_lr_5, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najleprza?

# %%
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr_1, y_f_lr_1, 'g');
plt.plot(x_f_lr_2, y_f_lr_2, 'r');
plt.plot(x_f_lr_3, y_f_lr_3, 'b');
plt.plot(x_f_lr_4, y_f_lr_4, 'y');
plt.plot(x_f_lr_5, y_f_lr_5, 'c*');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
import statsmodels.api as sm
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()

# %%
print(Res1.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.509
# Dependent Variable: y                AIC:                633.0210
# Date:               2021-03-26 10:52 BIC:                638.2314
# No. Observations:   100              Log-Likelihood:     -314.51
# Df Model:           1                F-statistic:        103.5
# Df Residuals:       98               Prob (F-statistic): 5.04e-17
# R-squared:          0.514            Scale:              32.218
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const     -2.9953     1.0635   -2.8164   0.0059   -5.1059   -0.8848
# x1         6.5826     0.6469   10.1752   0.0000    5.2988    7.8665
# -----------------------------------------------------------------
# Omnibus:              24.490       Durbin-Watson:          2.201
# Prob(Omnibus):        0.000        Jarque-Bera (JB):       36.786
# Skew:                 1.111        Prob(JB):               0.000
# Kurtosis:             4.972        Condition No.:          4
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.804
# Dependent Variable: y                AIC:                542.3374
# Date:               2021-03-26 10:52 BIC:                550.1530
# No. Observations:   100              Log-Likelihood:     -268.17
# Df Model:           2                F-statistic:        203.5
# Df Residuals:       97               Prob (F-statistic): 1.96e-35
# R-squared:          0.808            Scale:              12.884
# -------------------------------------------------------------------
#          Coef.     Std.Err.      t      P>|t|     [0.025     0.975]
# -------------------------------------------------------------------
# const     5.8417     0.9898    5.9018   0.0000     3.8772    7.8062
# x1      -12.2976     1.6046   -7.6640   0.0000   -15.4823   -9.1129
# x2        6.4424     0.5294   12.1684   0.0000     5.3916    7.4931
# -----------------------------------------------------------------
# Omnibus:              2.144        Durbin-Watson:           2.019
# Prob(Omnibus):        0.342        Jarque-Bera (JB):        2.037
# Skew:                 0.267        Prob(JB):                0.361
# Kurtosis:             2.548        Condition No.:           22
# =================================================================

# %% [markdown]
# # Zadanie
# Analogiczne wyniki możemy izusklać za pomocą prostego kodu.

# %%
import statsmodels.formula.api as smf
# Turn the data into a pandas DataFrame, so that we
# can address them in the formulas with their name
df = pd.DataFrame({'x':x, 'y':y})

# Fit the models, and show the results
Res1F = smf.ols('y~x', df).fit()
Res2F = smf.ols('y ~ x+I(x**2)', df).fit()

# %%
print(Res1F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2F.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.514
# Model:                            OLS   Adj. R-squared:                  0.509
# Method:                 Least Squares   F-statistic:                     103.5
# Date:                Fri, 26 Mar 2021   Prob (F-statistic):           5.04e-17
# Time:                        10:53:46   Log-Likelihood:                -314.51
# No. Observations:                 100   AIC:                             633.0
# Df Residuals:                      98   BIC:                             638.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.9953      1.064     -2.816      0.006      -5.106      -0.885
# x              6.5826      0.647     10.175      0.000       5.299       7.866
# ==============================================================================
# Omnibus:                       24.490   Durbin-Watson:                   2.201
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.786
# Skew:                           1.111   Prob(JB):                     1.03e-08
# Kurtosis:                       4.972   Cond. No.                         3.97
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.808
# Model:                            OLS   Adj. R-squared:                  0.804
# Method:                 Least Squares   F-statistic:                     203.5
# Date:                Fri, 26 Mar 2021   Prob (F-statistic):           1.96e-35
# Time:                        10:53:46   Log-Likelihood:                -268.17
# No. Observations:                 100   AIC:                             542.3
# Df Residuals:                      97   BIC:                             550.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.8417      0.990      5.902      0.000       3.877       7.806
# x            -12.2976      1.605     -7.664      0.000     -15.482      -9.113
# I(x ** 2)      6.4424      0.529     12.168      0.000       5.392       7.493
# ==============================================================================
# Omnibus:                        2.144   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.342   Jarque-Bera (JB):                2.037
# Skew:                           0.267   Prob(JB):                        0.361
# Kurtosis:                       2.548   Cond. No.                         22.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()
Res3 = sm.OLS(y, M3).fit()
Res4 = sm.OLS(y, M4).fit()
Res5 = sm.OLS(y, M5).fit()
ellipses = "....................................."
aic = False

print(ellipses)
print("ax + b".ljust(len(ellipses), "."))
print(ellipses)
print(Res1.summary() if not aic else Res1.aic)

print(ellipses)
print("ax^2 + bx + c".ljust(len(ellipses), "."))
print(ellipses)
print(Res2.summary() if not aic else Res2.aic)

print(ellipses)
print("ax^3 + bx^2 + cx + d".ljust(len(ellipses), "."))
print(ellipses)
print(Res3.summary() if not aic else Res3.aic)

print(ellipses)
print("ax^4 + bx^3 + cx^2 + dx + e".ljust(len(ellipses), "."))
print(ellipses)
print(Res4.summary() if not aic else Res4.aic)
print(ellipses)

print("ax^5 + bx^4 + cx^3 + dx^2 + ex + f".ljust(len(ellipses), "."))
print(ellipses)
print(Res5.summary() if not aic else Res5.aic)
# Out:
# .....................................
# ax + b...............................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.514
# Model:                            OLS   Adj. R-squared:                  0.509
# Method:                 Least Squares   F-statistic:                     103.5
# Date:                Fri, 26 Mar 2021   Prob (F-statistic):           5.04e-17
# Time:                        14:37:55   Log-Likelihood:                -314.51
# No. Observations:                 100   AIC:                             633.0
# Df Residuals:                      98   BIC:                             638.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.9953      1.064     -2.816      0.006      -5.106      -0.885
# x1             6.5826      0.647     10.175      0.000       5.299       7.866
# ==============================================================================
# Omnibus:                       24.490   Durbin-Watson:                   2.201
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.786
# Skew:                           1.111   Prob(JB):                     1.03e-08
# Kurtosis:                       4.972   Cond. No.                         3.97
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# ax^2 + bx + c........................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.808
# Model:                            OLS   Adj. R-squared:                  0.804
# Method:                 Least Squares   F-statistic:                     203.5
# Date:                Fri, 26 Mar 2021   Prob (F-statistic):           1.96e-35
# Time:                        14:37:55   Log-Likelihood:                -268.17
# No. Observations:                 100   AIC:                             542.3
# Df Residuals:                      97   BIC:                             550.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.8417      0.990      5.902      0.000       3.877       7.806
# x1           -12.2976      1.605     -7.664      0.000     -15.482      -9.113
# x2             6.4424      0.529     12.168      0.000       5.392       7.493
# ==============================================================================
# Omnibus:                        2.144   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.342   Jarque-Bera (JB):                2.037
# Skew:                           0.267   Prob(JB):                        0.361
# Kurtosis:                       2.548   Cond. No.                         22.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# ax^3 + bx^2 + cx + d.................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     3520.
# Date:                Fri, 26 Mar 2021   Prob (F-statistic):           5.22e-98
# Time:                        14:37:55   Log-Likelihood:                -115.08
# No. Observations:                 100   AIC:                             238.2
# Df Residuals:                      96   BIC:                             248.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.7796      0.306    -12.349      0.000      -4.387      -3.172
# x1            26.2907      0.940     27.972      0.000      24.425      28.156
# x2           -25.5938      0.734    -34.887      0.000     -27.050     -24.138
# x3             7.0768      0.160     44.216      0.000       6.759       7.394
# ==============================================================================
# Omnibus:                        3.750   Durbin-Watson:                   2.135
# Prob(Omnibus):                  0.153   Jarque-Bera (JB):                3.658
# Skew:                           0.464   Prob(JB):                        0.161
# Kurtosis:                       2.867   Cond. No.                         164.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# ax^4 + bx^3 + cx^2 + dx + e..........
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 3.670e+04
# Date:                Fri, 26 Mar 2021   Prob (F-statistic):          1.57e-150
# Time:                        14:37:55   Log-Likelihood:                 16.618
# No. Observations:                 100   AIC:                            -23.24
# Df Residuals:                      95   BIC:                            -10.21
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.2068      0.110    -10.932      0.000      -1.426      -0.988
# x1            10.6013      0.514     20.613      0.000       9.580      11.622
# x2            -2.4544      0.689     -3.561      0.001      -3.823      -1.086
# x3            -4.8964      0.344    -14.219      0.000      -5.580      -4.213
# x4             1.9966      0.057     35.046      0.000       1.883       2.110
# ==============================================================================
# Omnibus:                        1.470   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.479   Jarque-Bera (JB):                1.437
# Skew:                           0.194   Prob(JB):                        0.487
# Kurtosis:                       2.559   Cond. No.                     1.22e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.22e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# .....................................
# ax^5 + bx^4 + cx^3 + dx^2 + ex + f...
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 2.923e+04
# Date:                Fri, 26 Mar 2021   Prob (F-statistic):          2.41e-148
# Time:                        14:37:55   Log-Likelihood:                 16.922
# No. Observations:                 100   AIC:                            -21.84
# Df Residuals:                      94   BIC:                            -6.213
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.2713      0.140     -9.107      0.000      -1.548      -0.994
# x1            11.1606      0.901     12.391      0.000       9.372      12.949
# x2            -3.7340      1.826     -2.045      0.044      -7.359      -0.109
# x3            -3.7611      1.538     -2.445      0.016      -6.816      -0.706
# x4             1.5699      0.566      2.772      0.007       0.445       2.694
# x5             0.0571      0.075      0.757      0.451      -0.093       0.207
# ==============================================================================
# Omnibus:                        1.716   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.424   Jarque-Bera (JB):                1.667
# Skew:                           0.228   Prob(JB):                        0.434
# Kurtosis:                       2.562   Cond. No.                     9.27e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.27e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
