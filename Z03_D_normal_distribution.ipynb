# %% [markdown]
# # 2-wymiarowy rozkład Normalny

# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.random as rnd
import scipy.stats as stats
from scipy.stats import multivariate_normal

# %% [markdown]
# # Zadanie
# Proszę wygenerować próbkę z rozkładu Normalnego
# $$
# m = [0,0]
# $$
#
# oraz
#
# $$
# \Sigma = [[4.40, -2.75], [-2.75,  5.50]]
# $$

# %%
mean1 = np.array([0, 0])
cov1 = np.array([[4.40, -2.75], [-2.75,  5.50]])
X1_rv=multivariate_normal(mean1, cov1, allow_singular=False)
X = X1_rv.rvs(1000)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
ax.scatter(X[:, 0], X[:, 1])
ax.set_xlim([-10,10])
ax.set_ylim([-10,10])
plt.show()

# %% [markdown]
# # Zadanie
# Proszę policzyć średnią oraz macierz kowariancji próbki.

# %%
means = X.mean(axis=0)
print(means)
cov = np.cov(X.T)
print(cov)
# Out:
# [ 0.00681713 -0.02476733]
# [[ 4.07060745 -2.57114782]
#  [-2.57114782  5.00430119]]

# %% [markdown]
# # Zadanie
# Proszę zdefiniować zmienną losową o razkładzie zadanym na podstawie empirycznej średniej i kowariancji oraz narysować na jednym wykresie:
#
# - próbkę
# - poziomice rozkładu normalnego

# %%
X2_rv=multivariate_normal(means, cov, allow_singular=False)
X2 = X2_rv.rvs(1000)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
ax.scatter(X2[:, 0], X2[:, 1])
ax.set_xlim([-10,10])
ax.set_ylim([-10,10])
x = np.linspace(-10,10,1000)
y = np.linspace(-10,10,1000)
X, Y = np.meshgrid(x, y)
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y
plt.contour(X, Y, X2_rv.pdf(pos), colors=['red'], levels=6)
plt.show()

# %% [markdown]
# # Zadanie
# Policz wektory i wartości własne macierzy kowariancji. Narysuj na jednym wykresie
#
# - próbkę
# - poziomice rozkładu normalnego
# - wektory własne macierzy kowariancji

# %%
from numpy import linalg
w, v = linalg.eig(cov)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
ax.scatter(X2[:, 0], X2[:, 1])
ax.set_xlim([-10,10])
ax.set_ylim([-10,10])
x = np.linspace(-10,10,1000)
y = np.linspace(-10,10,1000)
X, Y = np.meshgrid(x,y)
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y
plt.contour(X, Y, X2_rv.pdf(pos), colors=['red'], levels=6)

origin = means
eig_vec1 = v[:,0]
eig_vec2 = v[:,1]
plt.quiver(*origin, *eig_vec1, scale=6)
plt.quiver(*origin, *eig_vec2, scale=6)
plt.show()

# %% [markdown]
# # Zadanie
# Proszę wygenerować próbkę na kwadracie $[0,1] \times [0,1]$.
# Następnie proszę policzyć średnią oraz macierz kowariancji próbki.
#
# Narysuj na jednym wykresie
#
# - próbkę
# - poziomice rozkładu normalnego
# - wektory własne macierzy kowariancji

# %%
means = np.array([0.5, 0.5])
cov = np.eye(2)
X3_rv = sat(means, cov, allow_singular=False)
X3 = X3_rv.rvs(1000)
means3 = X3.mean(axis=0)
cov3 = np.cov(X3.T)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
ax.scatter(X3[:, 0], X3[:, 1])
ax.set_xlim([0,1])
ax.set_ylim([0,1])
x = np.linspace(0,1,1000)
y = np.linspace(0,1,1000)
X, Y = np.meshgrid(x,y)
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y
plt.contour(X, Y, X3_rv.pdf(pos), colors=['red'], levels=6)

w, v = linalg.eig(cov3)
origin = means3
eig_vec1 = v[:,0]
eig_vec2 = v[:,1]
plt.quiver(*origin, *eig_vec1, scale=6)
plt.quiver(*origin, *eig_vec2, scale=6)
plt.show()
